# %%
# !pip install spotipy
# Out:
# ...
#      |████████████████████████████████| 240 kB 4.3 MB/s eta 0:00:01
# ...
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 4.0.1
#     Uninstalling async-timeout-4.0.1:
#       Successfully uninstalled async-timeout-4.0.1
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %% [markdown]
# # EXTRACTION BEGINS

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="aa4cadbb94b24006b58a46b3e6162b4b", client_secret="0d896dea8df8492697b82eca88f2d8d8")

# %%
#creating a spotify object
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZF1DWSHg3zCMrBDf"

# %%
playlist_URI = playlist_link.split("/")[-1]

# %%
sp.playlist_tracks(playlist_URI)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWSHg3zCMrBDf/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-06-09T06:03:58Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3gYUwwn7FiiBMKHe36OUaQ'},
#        'href': 'https://api.spotify.com/v1/artists/3gYUwwn7FiiBMKHe36OUaQ',
#        'id': '3gYUwwn7FiiBMKHe36OUaQ',
#        'name': 'JZyNo',
#        'type': 'artist',
#        'uri': 'spotify:artist:3gYUwwn7FiiBMKHe36OUaQ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
# ...

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items']
# Out:
# [{'added_at': '2023-06-09T06:03:58Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3gYUwwn7FiiBMKHe36OUaQ'},
#       'href': 'https://api.spotify.com/v1/artists/3gYUwwn7FiiBMKHe36OUaQ',
#       'id': '3gYUwwn7FiiBMKHe36OUaQ',
#       'name': 'JZyNo',
#       'type': 'artist',
#       'uri': 'spotify:artist:3gYUwwn7FiiBMKHe36OUaQ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '7nJP3Rmr7nBGQ3OlrAvlb8'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Butta My Bread'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-04-07'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/7nJP3Rmr7nBGQ3OlrAvlb8'

# %%
#Getting Album information
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id': album_id, 'album_name': album_name, 'release_date': album_release_date,
                    'total_tracks': album_total_tracks, 'url': album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '7nJP3Rmr7nBGQ3OlrAvlb8',
#   'album_name': 'Butta My Bread',
#   'release_date': '2023-04-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7nJP3Rmr7nBGQ3OlrAvlb8'},
#  {'album_id': '27KnOMqnTWsnfBMXZ4YEuZ',
#   'album_name': 'Terminator',
#   'release_date': '2023-05-05',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/27KnOMqnTWsnfBMXZ4YEuZ'},
#  {'album_id': '1TGcgugu0CxUp5rhS7SyCW',
#   'album_name': 'Body & Soul',
#   'release_date': '2023-05-19',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/1TGcgugu0CxUp5rhS7SyCW'},
#  {'album_id': '7hAXzkLo3J1tLMMO3H74do',
#   'album_name': 'Carry Me Go',
#   'release_date': '2023-03-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7hAXzkLo3J1tLMMO3H74do'},
#  {'album_id': '2e7UIUu34tdxKVkcTG3463',
#   'album_name': 'L.I.T.A',
#   'release_date': '2023-06-02',
#   'total_tracks': 15,
# ...

# %%
#Getting Artist Information
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3gYUwwn7FiiBMKHe36OUaQ'},
#   'href': 'https://api.spotify.com/v1/artists/3gYUwwn7FiiBMKHe36OUaQ',
#   'id': '3gYUwwn7FiiBMKHe36OUaQ',
#   'name': 'JZyNo',
#   'type': 'artist',
#   'uri': 'spotify:artist:3gYUwwn7FiiBMKHe36OUaQ'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3WDXKsCKcxJhvrvpdg5IGI'},
#   'href': 'https://api.spotify.com/v1/artists/3WDXKsCKcxJhvrvpdg5IGI',
#   'id': '3WDXKsCKcxJhvrvpdg5IGI',
#   'name': 'Lasmid',
#   'type': 'artist',
#   'uri': 'spotify:artist:3WDXKsCKcxJhvrvpdg5IGI'}]

# %%
#considering an instance where one song has multiple artists
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {'artist_id': artist['id'], 'artist_ame': artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '3gYUwwn7FiiBMKHe36OUaQ',
#   'artist_ame': 'JZyNo',
#   'external_url': 'https://api.spotify.com/v1/artists/3gYUwwn7FiiBMKHe36OUaQ'},
#  {'artist_id': '3WDXKsCKcxJhvrvpdg5IGI',
#   'artist_ame': 'Lasmid',
#   'external_url': 'https://api.spotify.com/v1/artists/3WDXKsCKcxJhvrvpdg5IGI'},
#  {'artist_id': '4tIKaxUmpXzshok2yCnwdf',
#   'artist_ame': 'King Promise',
#   'external_url': 'https://api.spotify.com/v1/artists/4tIKaxUmpXzshok2yCnwdf'},
#  {'artist_id': '1XavfPKBpNjkOfxHINlMHF',
#   'artist_ame': 'Joeboy',
#   'external_url': 'https://api.spotify.com/v1/artists/1XavfPKBpNjkOfxHINlMHF'},
#  {'artist_id': '2mM6BxFQCd6BHzW4W7VhQP',
#   'artist_ame': 'Khaid',
#   'external_url': 'https://api.spotify.com/v1/artists/2mM6BxFQCd6BHzW4W7VhQP'},
#  {'artist_id': '6DUbLg2GQ7Dd7G9v6uwoPT',
#   'artist_ame': 'Boy Spyce',
#   'external_url': 'https://api.spotify.com/v1/artists/6DUbLg2GQ7Dd7G9v6uwoPT'},
#  {'artist_id': '6Z9Xe5mjocmPOhz2TLNrAi',
#   'artist_ame': 'Camidoh',
# ...

# %%
#Getting Song information
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '0DHUdmHzkNq7GAMaDLlJnb',
#   'song_name': 'Butta My Bread',
#   'duration_ms': 148672,
#   'url': 'https://open.spotify.com/track/0DHUdmHzkNq7GAMaDLlJnb',
#   'popularity': 64,
#   'song_added': '2023-06-09T06:03:58Z',
#   'album_id': '7nJP3Rmr7nBGQ3OlrAvlb8',
#   'artist_id': '3gYUwwn7FiiBMKHe36OUaQ'},
#  {'song_id': '1oq33HJBs0rDmjjZ2rVFyG',
#   'song_name': 'Terminator',
#   'duration_ms': 234024,
#   'url': 'https://open.spotify.com/track/1oq33HJBs0rDmjjZ2rVFyG',
#   'popularity': 61,
#   'song_added': '2023-06-09T06:03:58Z',
#   'album_id': '27KnOMqnTWsnfBMXZ4YEuZ',
#   'artist_id': '4tIKaxUmpXzshok2yCnwdf'},
#  {'song_id': '2AaZJAh9FifPCQdba87Hzr',
#   'song_name': 'Body & Soul',
#   'duration_ms': 154455,
#   'url': 'https://open.spotify.com/track/2AaZJAh9FifPCQdba87Hzr',
#   'popularity': 61,
#   'song_added': '2023-06-09T06:03:58Z',
#   'album_id': '1TGcgugu0CxUp5rhS7SyCW',
#   'artist_id': '1XavfPKBpNjkOfxHINlMHF'},
#  {'song_id': '7qxtOyjZ2zSaxBPH8fLyNi',
# ...

# %%
#Converting all Music information dictionaries into Pandas DataFrame
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id      album_name release_date  total_tracks  \
# 0  7nJP3Rmr7nBGQ3OlrAvlb8  Butta My Bread   2023-04-07             1
# 1  27KnOMqnTWsnfBMXZ4YEuZ      Terminator   2023-05-05             1
# 2  1TGcgugu0CxUp5rhS7SyCW     Body & Soul   2023-05-19            15
# 3  7hAXzkLo3J1tLMMO3H74do     Carry Me Go   2023-03-13             1
# 4  2e7UIUu34tdxKVkcTG3463         L.I.T.A   2023-06-02            15
#
#                                                  url
# 0  https://open.spotify.com/album/7nJP3Rmr7nBGQ3O...
# 1  https://open.spotify.com/album/27KnOMqnTWsnfBM...
# 2  https://open.spotify.com/album/1TGcgugu0CxUp5r...
# 3  https://open.spotify.com/album/7hAXzkLo3J1tLMM...
# 4  https://open.spotify.com/album/2e7UIUu34tdxKVk...

# %%
#checking if all the columns are in the right datatype
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   album_name    50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
#delete duplicates from album data
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
#Converting Artist list PdDataframe
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df
# Out:
#                  artist_id    artist_ame  \
# 0   3gYUwwn7FiiBMKHe36OUaQ         JZyNo
# 1   3WDXKsCKcxJhvrvpdg5IGI        Lasmid
# 2   4tIKaxUmpXzshok2yCnwdf  King Promise
# 3   1XavfPKBpNjkOfxHINlMHF        Joeboy
# 4   2mM6BxFQCd6BHzW4W7VhQP         Khaid
# ..                     ...           ...
# 86  3LOm0AZjpwVQebvkyanjDy  ODUMODUBLVCK
# 87  1X6cBGnXpEpN7CmflLKmLV   Kizz Daniel
# 88  3hPFJ4ShHVEAaL689YeblD        EMPIRE
# 89  4ovtyvs7j1jSmwhkBGHqSr       Olamide
# 90  3a1tBryiczPAZpgoZN9Rzg         Asake
#
#                                          external_url
# 0   https://api.spotify.com/v1/artists/3gYUwwn7Fii...
# 1   https://api.spotify.com/v1/artists/3WDXKsCKcxJ...
# 2   https://api.spotify.com/v1/artists/4tIKaxUmpXz...
# 3   https://api.spotify.com/v1/artists/1XavfPKBpNj...
# 4   https://api.spotify.com/v1/artists/2mM6BxFQCd6...
# ..                                                ...
# 86  https://api.spotify.com/v1/artists/3LOm0AZjpwV...
# ...

# %%
artist_df.head()
# Out:
#                 artist_id    artist_ame  \
# 0  3gYUwwn7FiiBMKHe36OUaQ         JZyNo
# 1  3WDXKsCKcxJhvrvpdg5IGI        Lasmid
# 2  4tIKaxUmpXzshok2yCnwdf  King Promise
# 3  1XavfPKBpNjkOfxHINlMHF        Joeboy
# 4  2mM6BxFQCd6BHzW4W7VhQP         Khaid
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/3gYUwwn7Fii...
# 1  https://api.spotify.com/v1/artists/3WDXKsCKcxJ...
# 2  https://api.spotify.com/v1/artists/4tIKaxUmpXz...
# 3  https://api.spotify.com/v1/artists/1XavfPKBpNj...
# 4  https://api.spotify.com/v1/artists/2mM6BxFQCd6...

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     91 non-null     object
#  1   artist_ame    91 non-null     object
#  2   external_url  91 non-null     object
# dtypes: object(3)
# memory usage: 2.3+ KB

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#Converting Song Dictionary into Pandas DataFrame
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id        song_name  duration_ms  \
# 0  0DHUdmHzkNq7GAMaDLlJnb   Butta My Bread       148672
# 1  1oq33HJBs0rDmjjZ2rVFyG       Terminator       234024
# 2  2AaZJAh9FifPCQdba87Hzr      Body & Soul       154455
# 3  7qxtOyjZ2zSaxBPH8fLyNi      Carry Me Go       136464
# 4  1MnLtHUkNjywtD2kyCiXXn  Brown Skin Girl       188415
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/0DHUdmHzkNq7GAM...          64
# 1  https://open.spotify.com/track/1oq33HJBs0rDmjj...          61
# 2  https://open.spotify.com/track/2AaZJAh9FifPCQd...          61
# 3  https://open.spotify.com/track/7qxtOyjZ2zSaxBP...          65
# 4  https://open.spotify.com/track/1MnLtHUkNjywtD2...          48
#
#              song_added                album_id               artist_id
# 0  2023-06-09T06:03:58Z  7nJP3Rmr7nBGQ3OlrAvlb8  3gYUwwn7FiiBMKHe36OUaQ
# 1  2023-06-09T06:03:58Z  27KnOMqnTWsnfBMXZ4YEuZ  4tIKaxUmpXzshok2yCnwdf
# ...

# %%
artist_df.head()
# Out:
#                 artist_id    artist_ame  \
# 0  3gYUwwn7FiiBMKHe36OUaQ         JZyNo
# 1  3WDXKsCKcxJhvrvpdg5IGI        Lasmid
# 2  4tIKaxUmpXzshok2yCnwdf  King Promise
# 3  1XavfPKBpNjkOfxHINlMHF        Joeboy
# 4  2mM6BxFQCd6BHzW4W7VhQP         Khaid
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/3gYUwwn7Fii...
# 1  https://api.spotify.com/v1/artists/3WDXKsCKcxJ...
# 2  https://api.spotify.com/v1/artists/4tIKaxUmpXz...
# 3  https://api.spotify.com/v1/artists/1XavfPKBpNj...
# 4  https://api.spotify.com/v1/artists/2mM6BxFQCd6...

# %%
album_df.head()
# Out:
#                  album_id      album_name release_date  total_tracks  \
# 0  7nJP3Rmr7nBGQ3OlrAvlb8  Butta My Bread   2023-04-07             1
# 1  27KnOMqnTWsnfBMXZ4YEuZ      Terminator   2023-05-05             1
# 2  1TGcgugu0CxUp5rhS7SyCW     Body & Soul   2023-05-19            15
# 3  7hAXzkLo3J1tLMMO3H74do     Carry Me Go   2023-03-13             1
# 4  2e7UIUu34tdxKVkcTG3463         L.I.T.A   2023-06-02            15
#
#                                                  url
# 0  https://open.spotify.com/album/7nJP3Rmr7nBGQ3O...
# 1  https://open.spotify.com/album/27KnOMqnTWsnfBM...
# 2  https://open.spotify.com/album/1TGcgugu0CxUp5r...
# 3  https://open.spotify.com/album/7hAXzkLo3J1tLMM...
# 4  https://open.spotify.com/album/2e7UIUu34tdxKVk...

# %% [markdown]
# # TRANSFORMATION BEGINS

# %%
#Correcting date data type
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      41 non-null     object
#  1   album_name    41 non-null     object
#  2   release_date  41 non-null     datetime64[ns]
#  3   total_tracks  41 non-null     int64
#  4   url           41 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 1.9+ KB

# %%
#correcting song added data type
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
